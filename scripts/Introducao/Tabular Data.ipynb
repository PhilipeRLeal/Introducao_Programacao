# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_static/pandas.svg">
#
# ## O excel da programação
#
# [Documentação](https://pandas.pydata.org):

# %% [markdown]
# Agora que já vimos os tipos primitivos, não primitivos e customizados de objetos em Python, podemos seguir com classes de objetos mais complexos; O caso exemplo é a biblioteca Pandas, a qual é otimizada para operações tabulares (e.g., tal qual o **Microsoft Excel**).

# %% [markdown]
# # Estruturas do Pandas:
#
#
#
# 1.   Series
# 2.   DataFrame
#
#
#
# [Veja aqui](https://pandas.pydata.org/docs/user_guide/dsintro.html)

# %% [markdown]
# ## DataFrames
#
# <img src="https://pandas.pydata.org/docs/_images/01_table_dataframe.svg">

# %% [markdown]
# ## Cada coluna de umDataFrame é uma Series
#
# <img src="https://pandas.pydata.org/docs/_images/01_table_series.svg">

# %% [markdown]
# # Operações de I.O. (Input-Output)
#
# <img src="https://pandas.pydata.org/docs/_images/02_io_readwrite.svg">
#
#
# [Getting start with Pandas](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html)

# %%
# Listagem dos tipos de IO do Pandas

import pandas as pd

df = pd.read_html('https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html')[0]

df
# Out:
#    Format Type       Data Description          Reader           Writer
# 0         text                    CSV        read_csv           to_csv
# 1         text  Fixed-Width Text File        read_fwf              NaN
# 2         text                   JSON       read_json          to_json
# 3         text                   HTML       read_html          to_html
# 4         text                  LaTeX             NaN  Styler.to_latex
# 5         text                    XML        read_xml           to_xml
# 6         text        Local clipboard  read_clipboard     to_clipboard
# 7       binary               MS Excel      read_excel         to_excel
# 8       binary           OpenDocument      read_excel              NaN
# 9       binary            HDF5 Format        read_hdf           to_hdf
# 10      binary         Feather Format    read_feather       to_feather
# 11      binary         Parquet Format    read_parquet       to_parquet
# ...

# %% [markdown]
# # Operações Tabulares:
#
#
# *   Melt
# *   Pivot
# *   Aggregation
# *   stack

# %% [markdown]
# ## Video 1
#
# [<img src="https://img.youtube.com/vi/DCqWZ0DGVqw/maxresdefault.jpg" width="50%">](https://youtu.be/DCqWZ0DGVqw)
#
#
# ## Video 2: Melting operations
# [<img src="https://img.youtube.com/vi/oY62o-tBHF4/maxresdefault.jpg" width="50%">](https://youtu.be/oY62o-tBHF4)
#
#
# ## Vídeo 3
# [<img src="https://i.ytimg.com/vi/ZuTfB5NWOYE/hqdefault.jpg" width="50%">](https://youtu.be/ZuTfB5NWOYE)
#
#
# ## Video 4
#
# [<img src="https://img.youtube.com/vi/oazUQPrs8nw/maxresdefault.jpg" width="50%">](https://youtu.be/oazUQPrs8nw)
